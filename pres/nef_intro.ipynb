# %%
# install numpy and nengo
# sudo pip install nengo 
# sudo pip install numpy
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import nengo
# %load_ext nengo.ipynb
from nengo.dists import Uniform
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot, set_color_cycle
set_color_cycle(["#377EB8", "#E41A1C", "#4DAF4A", "#984EA3", "#FF7F00", "#222222", "#A65628", "#E7298A"])

def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1],[-1]], (n_neurons/2,1))
    intercepts *= encoders[:,0]
    return intercepts, encoders

hide_input()
# Out:
#         <a id="1084466705" href="javascript:toggle_input_1084466705()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1084466705;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1084466705 = document.getElementById("1084466705");
#                 var cell = link_1084466705;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1084466705;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1084466705 = cell.children[i];
#                 }
#                 input_1084466705.style.display = "none"; // hide
#
#                 toggle_input_1084466705 = function() {
#                     if (input_1084466705.style.display == "none") {
#                         input_1084466705.style.display = ""; // show
#                         link_1084466705.innerHTML = "Hide Input";
#                     } else {
#                         input_1084466705.style.display = "none"; // hide
#                         link_1084466705.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1084466705 = $("a[id='1084466705']");
#                 var cell_1084466705 = link_1084466705.parents("div.cell:first");
#                 var input_1084466705 = cell_1084466705.children("div.input");
#                 input_1084466705.hide();
#
#                 toggle_input_1084466705 = function() {
#                     if (input_1084466705.is(':hidden')) {
#                         input_1084466705.slideDown();
#                         link_1084466705[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1084466705.slideUp();
#                         link_1084466705[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# # Introduction
# The Neural Engineering Framework (NEF) is the set of theoretical methods that are used in Nengo for constructing neural models.  The NEF is based on <a href="http://www.amazon.com/gp/product/0262550601">Eliasmith & Anderson's (2003) book</a> from MIT Press. This notebook introduces the three main principles discussed in that book and implemented in Nengo.

# %% [markdown]
# # Principle 1: Representation
#
# ## Encoding
#
# Neural populations represent time-varying signals through their spiking responses. A signal is a vector of real numbers of arbitrary length. This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1);
hide_input()
# Out:
# /home/caxenie/.local/lib/python2.7/site-packages/nengo/cache.py:202: UserWarning: Decoder cache could not acquire lock and was deactivated.
#   "Decoder cache could not acquire lock and was deactivated.")
# /home/caxenie/.local/lib/python2.7/site-packages/nengo/cache.py:143: UserWarning: Decoder cache index could not acquire lock. Cache index was not synced.
#   "Decoder cache index could not acquire lock. "
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"
#         <a id="1255151698" href="javascript:toggle_input_1255151698()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1255151698;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1255151698 = document.getElementById("1255151698");
#                 var cell = link_1255151698;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1255151698;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1255151698 = cell.children[i];
#                 }
#                 input_1255151698.style.display = "none"; // hide
#
#                 toggle_input_1255151698 = function() {
#                     if (input_1255151698.style.display == "none") {
#                         input_1255151698.style.display = ""; // show
#                         link_1255151698.innerHTML = "Hide Input";
#                     } else {
#                         input_1255151698.style.display = "none"; // hide
#                         link_1255151698.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1255151698 = $("a[id='1255151698']");
#                 var cell_1255151698 = link_1255151698.parents("div.cell:first");
#                 var input_1255151698 = cell_1255151698.children("div.input");
#                 input_1255151698.hide();
#
#                 toggle_input_1255151698 = function() {
#                     if (input_1255151698.is(':hidden')) {
#                         input_1255151698.slideDown();
#                         link_1255151698[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1255151698.slideUp();
#                         link_1255151698[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations based on each neuron's *tuning curve* (which is similar to the I-F (current-frequency) curve, if you're familiar with that).
#
# The tuning curve describes how much a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(8, dimensions=1,
                       intercepts=intercepts,
                       max_rates=Uniform(80, 100), 
                       encoders=encoders)

# %%
with nengo.Simulator(model) as sim:

    eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)");
hide_input()
# Out:
#         <a id="332938084" href="javascript:toggle_input_332938084()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_332938084;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_332938084 = document.getElementById("332938084");
#                 var cell = link_332938084;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_332938084;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_332938084 = cell.children[i];
#                 }
#                 input_332938084.style.display = "none"; // hide
#
#                 toggle_input_332938084 = function() {
#                     if (input_332938084.style.display == "none") {
#                         input_332938084.style.display = ""; // show
#                         link_332938084.innerHTML = "Hide Input";
#                     } else {
#                         input_332938084.style.display = "none"; // hide
#                         link_332938084.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_332938084 = $("a[id='332938084']");
#                 var cell_332938084 = link_332938084.parents("div.cell:first");
#                 var input_332938084 = cell_332938084.children("div.input");
#                 input_332938084.hide();
#
#                 toggle_input_332938084 = function() {
#                     if (input_332938084.is(':hidden')) {
#                         input_332938084.slideDown();
#                         link_332938084[0].innerHTML = "Hide Input";
#                     } else {
#                         input_332938084.slideUp();
#                         link_332938084[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel('Neuron')
ax.set_xlabel('Time (s)');
hide_input()
# Out:
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"
#         <a id="705286250" href="javascript:toggle_input_705286250()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_705286250;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_705286250 = document.getElementById("705286250");
#                 var cell = link_705286250;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_705286250;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_705286250 = cell.children[i];
#                 }
#                 input_705286250.style.display = "none"; // hide
#
#                 toggle_input_705286250 = function() {
#                     if (input_705286250.style.display == "none") {
#                         input_705286250.style.display = ""; // show
#                         link_705286250.innerHTML = "Hide Input";
#                     } else {
#                         input_705286250.style.display = "none"; // hide
#                         link_705286250.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_705286250 = $("a[id='705286250']");
#                 var cell_705286250 = link_705286250.parents("div.cell:first");
#                 var input_705286250 = cell_705286250.children("div.input");
#                 input_705286250.hide();
#
#                 toggle_input_705286250 = function() {
#                     if (input_705286250.is(':hidden')) {
#                         input_705286250.slideDown();
#                         link_705286250[0].innerHTML = "Hide Input";
#                     } else {
#                         input_705286250.slideUp();
#                         link_705286250[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Decoding
#
# We can estimate the input signal originally encoded by decoding the pattern of spikes. To do this, we first filter the spike train with a temporal filter that accounts for postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(8, dimensions=1,
                       intercepts=intercepts,
                       max_rates=Uniform(80, 100), 
                       encoders=encoders)
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:,i] - i*scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons+1), scale)
plt.ylabel("Neuron")
plt.yticks(np.arange(scale/1.8, (-A.n_neurons + 1) * scale, -scale), np.arange(A.n_neurons));
hide_input()
# Out:
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"
#         <a id="1696691238" href="javascript:toggle_input_1696691238()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1696691238;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1696691238 = document.getElementById("1696691238");
#                 var cell = link_1696691238;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1696691238;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1696691238 = cell.children[i];
#                 }
#                 input_1696691238.style.display = "none"; // hide
#
#                 toggle_input_1696691238 = function() {
#                     if (input_1696691238.style.display == "none") {
#                         input_1696691238.style.display = ""; // show
#                         link_1696691238.innerHTML = "Hide Input";
#                     } else {
#                         input_1696691238.style.display = "none"; // hide
#                         link_1696691238.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1696691238 = $("a[id='1696691238']");
#                 var cell_1696691238 = link_1696691238.parents("div.cell:first");
#                 var input_1696691238 = cell_1696691238.children("div.input");
#                 input_1696691238.hide();
#
#                 toggle_input_1696691238 = function() {
#                     if (input_1696691238.is(':hidden')) {
#                         input_1696691238.slideDown();
#                         link_1696691238[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1696691238.slideUp();
#                         link_1696691238[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains with decoding weights and sum them together to give an estimate of the input based on the spikes.
#
# The decoding weights are determined by minimizing the squared difference between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1);
hide_input()
# Out:
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"
#         <a id="171880771" href="javascript:toggle_input_171880771()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_171880771;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_171880771 = document.getElementById("171880771");
#                 var cell = link_171880771;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_171880771;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_171880771 = cell.children[i];
#                 }
#                 input_171880771.style.display = "none"; // hide
#
#                 toggle_input_171880771 = function() {
#                     if (input_171880771.style.display == "none") {
#                         input_171880771.style.display = ""; // show
#                         link_171880771.innerHTML = "Hide Input";
#                     } else {
#                         input_171880771.style.display = "none"; // hide
#                         link_171880771.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_171880771 = $("a[id='171880771']");
#                 var cell_171880771 = link_171880771.parents("div.cell:first");
#                 var input_171880771 = cell_171880771.children("div.input");
#                 input_171880771.hide();
#
#                 toggle_input_171880771 = function() {
#                     if (input_171880771.is(':hidden')) {
#                         input_171880771.slideDown();
#                         link_171880771[0].innerHTML = "Hide Input";
#                     } else {
#                         input_171880771.slideUp();
#                         link_171880771[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1);
hide_input()
# Out:
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"
#         <a id="2070933891" href="javascript:toggle_input_2070933891()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2070933891;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2070933891 = document.getElementById("2070933891");
#                 var cell = link_2070933891;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2070933891;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_2070933891 = cell.children[i];
#                 }
#                 input_2070933891.style.display = "none"; // hide
#
#                 toggle_input_2070933891 = function() {
#                     if (input_2070933891.style.display == "none") {
#                         input_2070933891.style.display = ""; // show
#                         link_2070933891.innerHTML = "Hide Input";
#                     } else {
#                         input_2070933891.style.display = "none"; // hide
#                         link_2070933891.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2070933891 = $("a[id='2070933891']");
#                 var cell_2070933891 = link_2070933891.parents("div.cell:first");
#                 var input_2070933891 = cell_2070933891.children("div.input");
#                 input_2070933891.hide();
#
#                 toggle_input_2070933891 = function() {
#                     if (input_2070933891.is(':hidden')) {
#                         input_2070933891.slideDown();
#                         link_2070933891[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2070933891.slideUp();
#                         link_2070933891[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
from nengo.processes import WhiteSignal

model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron");
hide_input()
# Out:
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"
#         <a id="604293958" href="javascript:toggle_input_604293958()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_604293958;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_604293958 = document.getElementById("604293958");
#                 var cell = link_604293958;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_604293958;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_604293958 = cell.children[i];
#                 }
#                 input_604293958.style.display = "none"; // hide
#
#                 toggle_input_604293958 = function() {
#                     if (input_604293958.style.display == "none") {
#                         input_604293958.style.display = ""; // show
#                         link_604293958.innerHTML = "Hide Input";
#                     } else {
#                         input_604293958.style.display = "none"; // hide
#                         link_604293958.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_604293958 = $("a[id='604293958']");
#                 var cell_604293958 = link_604293958.parents("div.cell:first");
#                 var input_604293958 = cell_604293958.children("div.input");
#                 input_604293958.hide();
#
#                 toggle_input_604293958 = function() {
#                     if (input_604293958.is(':hidden')) {
#                         input_604293958.slideDown();
#                         link_604293958[0].innerHTML = "Hide Input";
#                     } else {
#                         input_604293958.slideUp();
#                         link_604293958[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# # Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time, and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal, not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input,)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[Asquare_probe], label="Decoded esimate")
plt.plot(sim.trange(), np.square(sim.data[input_probe]), label="Input signal squared")
plt.legend(loc="best", fontsize='medium')
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron");
hide_input()
# Out:
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"
#         <a id="1667522014" href="javascript:toggle_input_1667522014()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1667522014;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1667522014 = document.getElementById("1667522014");
#                 var cell = link_1667522014;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1667522014;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1667522014 = cell.children[i];
#                 }
#                 input_1667522014.style.display = "none"; // hide
#
#                 toggle_input_1667522014 = function() {
#                     if (input_1667522014.style.display == "none") {
#                         input_1667522014.style.display = ""; // show
#                         link_1667522014.innerHTML = "Hide Input";
#                     } else {
#                         input_1667522014.style.display = "none"; // hide
#                         link_1667522014.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1667522014 = $("a[id='1667522014']");
#                 var cell_1667522014 = link_1667522014.parents("div.cell:first");
#                 var input_1667522014 = cell_1667522014.children("div.input");
#                 input_1667522014.hide();
#
#                 toggle_input_1667522014 = function() {
#                     if (input_1667522014.is(':hidden')) {
#                         input_1667522014.slideDown();
#                         link_1667522014[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1667522014.slideUp();
#                         link_1667522014[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same. The only difference is how we're interpreting those spikes. We told Nengo to compute a new set of decoders that estimate the function $x^2$.
#
# In general, the transformation principle determines how we can decode spike trains to compute linear and nonlinear transformations of signals encoded in a population of neurons. We can then project those transformed signals into another population, and repeat the process.  Essentially, this provides a means of computing the neural connection weights to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron");
hide_input()
# Out:
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"
#         <a id="1187291864" href="javascript:toggle_input_1187291864()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1187291864;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1187291864 = document.getElementById("1187291864");
#                 var cell = link_1187291864;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1187291864;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1187291864 = cell.children[i];
#                 }
#                 input_1187291864.style.display = "none"; // hide
#
#                 toggle_input_1187291864 = function() {
#                     if (input_1187291864.style.display == "none") {
#                         input_1187291864.style.display = ""; // show
#                         link_1187291864.innerHTML = "Hide Input";
#                     } else {
#                         input_1187291864.style.display = "none"; // hide
#                         link_1187291864.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1187291864 = $("a[id='1187291864']");
#                 var cell_1187291864 = link_1187291864.parents("div.cell:first");
#                 var input_1187291864 = cell_1187291864.children("div.input");
#                 input_1187291864.hide();
#
#                 toggle_input_1187291864 = function() {
#                     if (input_1187291864.is(':hidden')) {
#                         input_1187291864.slideDown();
#                         link_1187291864[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1187291864.slideUp();
#                         link_1187291864[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal involve solving for the usual decoders, and scaling those decoding weights. Let us flip this sine wave upside down as it is transmitted between two populations (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2,2,3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2,2,2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2,2,4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron");
hide_input()
# Out:
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"
#         <a id="2060310509" href="javascript:toggle_input_2060310509()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2060310509;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2060310509 = document.getElementById("2060310509");
#                 var cell = link_2060310509;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2060310509;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_2060310509 = cell.children[i];
#                 }
#                 input_2060310509.style.display = "none"; // hide
#
#                 toggle_input_2060310509 = function() {
#                     if (input_2060310509.style.display == "none") {
#                         input_2060310509.style.display = ""; // show
#                         link_2060310509.innerHTML = "Hide Input";
#                     } else {
#                         input_2060310509.style.display = "none"; // hide
#                         link_2060310509.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2060310509 = $("a[id='2060310509']");
#                 var cell_2060310509 = link_2060310509.parents("div.cell:first");
#                 var input_2060310509 = cell_2060310509.children("div.input");
#                 input_2060310509.hide();
#
#                 toggle_input_2060310509 = function() {
#                     if (input_2060310509.is(':hidden')) {
#                         input_2060310509.slideDown();
#                         link_2060310509[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2060310509.slideUp();
#                         link_2060310509[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve solving for a new set of decoding weights. Let us add a third population connected to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color='k')
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color='k')
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color='k')
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron");
hide_input()
# Out:
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"
#         <a id="1556857989" href="javascript:toggle_input_1556857989()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1556857989;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1556857989 = document.getElementById("1556857989");
#                 var cell = link_1556857989;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1556857989;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1556857989 = cell.children[i];
#                 }
#                 input_1556857989.style.display = "none"; // hide
#
#                 toggle_input_1556857989 = function() {
#                     if (input_1556857989.style.display == "none") {
#                         input_1556857989.style.display = ""; // show
#                         link_1556857989.innerHTML = "Hide Input";
#                     } else {
#                         input_1556857989.style.display = "none"; // hide
#                         link_1556857989.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1556857989 = $("a[id='1556857989']");
#                 var cell_1556857989 = link_1556857989.parents("div.cell:first");
#                 var input_1556857989 = cell_1556857989.children("div.input");
#                 input_1556857989.hide();
#
#                 toggle_input_1556857989 = function() {
#                     if (input_1556857989.is(':hidden')) {
#                         input_1556857989.slideDown();
#                         link_1556857989[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1556857989.slideUp();
#                         link_1556857989[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# # Principle 3: Dynamics
#
# So far, we have been considering the values represented by ensembles as generic "signals." However, if we think of them instead as state variables in a dynamical system, then we can apply the methods of control theory or dynamic systems theory to brain models.  Nengo automatically translates from standard dynamical systems descriptions to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics, we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator implemented using this third principle. It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1,0] if t < 0.1 else [0,0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(oscillator, oscillator,
                     transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel('Time (s)')

plt.subplot(1,2,2)
plt.plot(sim.data[oscillator_probe][:,0], sim.data[oscillator_probe][:,1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$');
hide_input()
# Out:
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"
#         <a id="593080431" href="javascript:toggle_input_593080431()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_593080431;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_593080431 = document.getElementById("593080431");
#                 var cell = link_593080431;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_593080431;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_593080431 = cell.children[i];
#                 }
#                 input_593080431.style.display = "none"; // hide
#
#                 toggle_input_593080431 = function() {
#                     if (input_593080431.style.display == "none") {
#                         input_593080431.style.display = ""; // show
#                         link_593080431.innerHTML = "Hide Input";
#                     } else {
#                         input_593080431.style.display = "none"; // hide
#                         link_593080431.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_593080431 = $("a[id='593080431']");
#                 var cell_593080431 = link_593080431.parents("div.cell:first");
#                 var input_593080431 = cell_593080431.children("div.input");
#                 input_593080431.hide();
#
#                 toggle_input_593080431 = function() {
#                     if (input_593080431.is(':hidden')) {
#                         input_593080431.slideDown();
#                         link_593080431[0].innerHTML = "Hide Input";
#                     } else {
#                         input_593080431.slideUp();
#                         link_593080431[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
