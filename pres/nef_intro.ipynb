# %%
# install numpy and nengo
# sudo pip install nengo 
# sudo pip install numpy
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import nengo
# %load_ext nengo.ipynb
from nengo.dists import Uniform
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot, set_color_cycle
set_color_cycle(["#377EB8", "#E41A1C", "#4DAF4A", "#984EA3", "#FF7F00", "#222222", "#A65628", "#E7298A"])

def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1],[-1]], (n_neurons/2,1))
    intercepts *= encoders[:,0]
    return intercepts, encoders

hide_input()
# Out:
#         <a id="1939048720" href="javascript:toggle_input_1939048720()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1939048720;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1939048720 = document.getElementById("1939048720");
#                 var cell = link_1939048720;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1939048720;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1939048720 = cell.children[i];
#                 }
#                 input_1939048720.style.display = "none"; // hide
#
#                 toggle_input_1939048720 = function() {
#                     if (input_1939048720.style.display == "none") {
#                         input_1939048720.style.display = ""; // show
#                         link_1939048720.innerHTML = "Hide Input";
#                     } else {
#                         input_1939048720.style.display = "none"; // hide
#                         link_1939048720.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1939048720 = $("a[id='1939048720']");
#                 var cell_1939048720 = link_1939048720.parents("div.cell:first");
#                 var input_1939048720 = cell_1939048720.children("div.input");
#                 input_1939048720.hide();
#
#                 toggle_input_1939048720 = function() {
#                     if (input_1939048720.is(':hidden')) {
#                         input_1939048720.slideDown();
#                         link_1939048720[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1939048720.slideUp();
#                         link_1939048720[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# # Introduction
# The Neural Engineering Framework (NEF) is the set of theoretical methods that are used in Nengo for constructing neural models.  The NEF is based on <a href="http://www.amazon.com/gp/product/0262550601">Eliasmith & Anderson's (2003) book</a> from MIT Press. This notebook introduces the three main principles discussed in that book and implemented in Nengo.

# %% [markdown]
# # Principle 1: Representation
#
# ## Encoding
#
# Neural populations represent time-varying signals through their spiking responses. A signal is a vector of real numbers of arbitrary length. This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1);
hide_input()
# Out:
# /home/caxenie/.local/lib/python2.7/site-packages/nengo/cache.py:202: UserWarning: Decoder cache could not acquire lock and was deactivated.
#   "Decoder cache could not acquire lock and was deactivated.")
# /home/caxenie/.local/lib/python2.7/site-packages/nengo/cache.py:143: UserWarning: Decoder cache index could not acquire lock. Cache index was not synced.
#   "Decoder cache index could not acquire lock. "
#         <a id="1306541862" href="javascript:toggle_input_1306541862()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1306541862;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1306541862 = document.getElementById("1306541862");
#                 var cell = link_1306541862;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1306541862;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1306541862 = cell.children[i];
#                 }
#                 input_1306541862.style.display = "none"; // hide
#
#                 toggle_input_1306541862 = function() {
#                     if (input_1306541862.style.display == "none") {
#                         input_1306541862.style.display = ""; // show
#                         link_1306541862.innerHTML = "Hide Input";
#                     } else {
#                         input_1306541862.style.display = "none"; // hide
#                         link_1306541862.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1306541862 = $("a[id='1306541862']");
#                 var cell_1306541862 = link_1306541862.parents("div.cell:first");
#                 var input_1306541862 = cell_1306541862.children("div.input");
#                 input_1306541862.hide();
#
#                 toggle_input_1306541862 = function() {
#                     if (input_1306541862.is(':hidden')) {
#                         input_1306541862.slideDown();
#                         link_1306541862[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1306541862.slideUp();
#                         link_1306541862[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations based on each neuron's *tuning curve* (which is similar to the I-F (current-frequency) curve, if you're familiar with that).
#
# The tuning curve describes how much a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(8, dimensions=1,
                       intercepts=intercepts,
                       max_rates=Uniform(80, 100), 
                       encoders=encoders)

# %%
with nengo.Simulator(model) as sim:

    eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)");
hide_input()
# Out:
#         <a id="567136842" href="javascript:toggle_input_567136842()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_567136842;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_567136842 = document.getElementById("567136842");
#                 var cell = link_567136842;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_567136842;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_567136842 = cell.children[i];
#                 }
#                 input_567136842.style.display = "none"; // hide
#
#                 toggle_input_567136842 = function() {
#                     if (input_567136842.style.display == "none") {
#                         input_567136842.style.display = ""; // show
#                         link_567136842.innerHTML = "Hide Input";
#                     } else {
#                         input_567136842.style.display = "none"; // hide
#                         link_567136842.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_567136842 = $("a[id='567136842']");
#                 var cell_567136842 = link_567136842.parents("div.cell:first");
#                 var input_567136842 = cell_567136842.children("div.input");
#                 input_567136842.hide();
#
#                 toggle_input_567136842 = function() {
#                     if (input_567136842.is(':hidden')) {
#                         input_567136842.slideDown();
#                         link_567136842[0].innerHTML = "Hide Input";
#                     } else {
#                         input_567136842.slideUp();
#                         link_567136842[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel('Neuron')
ax.set_xlabel('Time (s)');
hide_input()
# Out:
#         <a id="1701747459" href="javascript:toggle_input_1701747459()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1701747459;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1701747459 = document.getElementById("1701747459");
#                 var cell = link_1701747459;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1701747459;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1701747459 = cell.children[i];
#                 }
#                 input_1701747459.style.display = "none"; // hide
#
#                 toggle_input_1701747459 = function() {
#                     if (input_1701747459.style.display == "none") {
#                         input_1701747459.style.display = ""; // show
#                         link_1701747459.innerHTML = "Hide Input";
#                     } else {
#                         input_1701747459.style.display = "none"; // hide
#                         link_1701747459.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1701747459 = $("a[id='1701747459']");
#                 var cell_1701747459 = link_1701747459.parents("div.cell:first");
#                 var input_1701747459 = cell_1701747459.children("div.input");
#                 input_1701747459.hide();
#
#                 toggle_input_1701747459 = function() {
#                     if (input_1701747459.is(':hidden')) {
#                         input_1701747459.slideDown();
#                         link_1701747459[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1701747459.slideUp();
#                         link_1701747459[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Decoding
#
# We can estimate the input signal originally encoded by decoding the pattern of spikes. To do this, we first filter the spike train with a temporal filter that accounts for postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(8, dimensions=1,
                       intercepts=intercepts,
                       max_rates=Uniform(80, 100), 
                       encoders=encoders)
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:,i] - i*scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons+1), scale)
plt.ylabel("Neuron")
plt.yticks(np.arange(scale/1.8, (-A.n_neurons + 1) * scale, -scale), np.arange(A.n_neurons));
hide_input()
# Out:
#         <a id="1935026993" href="javascript:toggle_input_1935026993()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1935026993;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1935026993 = document.getElementById("1935026993");
#                 var cell = link_1935026993;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1935026993;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1935026993 = cell.children[i];
#                 }
#                 input_1935026993.style.display = "none"; // hide
#
#                 toggle_input_1935026993 = function() {
#                     if (input_1935026993.style.display == "none") {
#                         input_1935026993.style.display = ""; // show
#                         link_1935026993.innerHTML = "Hide Input";
#                     } else {
#                         input_1935026993.style.display = "none"; // hide
#                         link_1935026993.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1935026993 = $("a[id='1935026993']");
#                 var cell_1935026993 = link_1935026993.parents("div.cell:first");
#                 var input_1935026993 = cell_1935026993.children("div.input");
#                 input_1935026993.hide();
#
#                 toggle_input_1935026993 = function() {
#                     if (input_1935026993.is(':hidden')) {
#                         input_1935026993.slideDown();
#                         link_1935026993[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1935026993.slideUp();
#                         link_1935026993[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains with decoding weights and sum them together to give an estimate of the input based on the spikes.
#
# The decoding weights are determined by minimizing the squared difference between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1);
hide_input()
# Out:
#         <a id="1840963724" href="javascript:toggle_input_1840963724()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1840963724;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1840963724 = document.getElementById("1840963724");
#                 var cell = link_1840963724;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1840963724;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1840963724 = cell.children[i];
#                 }
#                 input_1840963724.style.display = "none"; // hide
#
#                 toggle_input_1840963724 = function() {
#                     if (input_1840963724.style.display == "none") {
#                         input_1840963724.style.display = ""; // show
#                         link_1840963724.innerHTML = "Hide Input";
#                     } else {
#                         input_1840963724.style.display = "none"; // hide
#                         link_1840963724.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1840963724 = $("a[id='1840963724']");
#                 var cell_1840963724 = link_1840963724.parents("div.cell:first");
#                 var input_1840963724 = cell_1840963724.children("div.input");
#                 input_1840963724.hide();
#
#                 toggle_input_1840963724 = function() {
#                     if (input_1840963724.is(':hidden')) {
#                         input_1840963724.slideDown();
#                         link_1840963724[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1840963724.slideUp();
#                         link_1840963724[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1);
hide_input()
# Out:
#         <a id="1016790172" href="javascript:toggle_input_1016790172()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1016790172;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1016790172 = document.getElementById("1016790172");
#                 var cell = link_1016790172;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1016790172;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1016790172 = cell.children[i];
#                 }
#                 input_1016790172.style.display = "none"; // hide
#
#                 toggle_input_1016790172 = function() {
#                     if (input_1016790172.style.display == "none") {
#                         input_1016790172.style.display = ""; // show
#                         link_1016790172.innerHTML = "Hide Input";
#                     } else {
#                         input_1016790172.style.display = "none"; // hide
#                         link_1016790172.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1016790172 = $("a[id='1016790172']");
#                 var cell_1016790172 = link_1016790172.parents("div.cell:first");
#                 var input_1016790172 = cell_1016790172.children("div.input");
#                 input_1016790172.hide();
#
#                 toggle_input_1016790172 = function() {
#                     if (input_1016790172.is(':hidden')) {
#                         input_1016790172.slideDown();
#                         link_1016790172[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1016790172.slideUp();
#                         link_1016790172[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
from nengo.processes import WhiteSignal

model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron");
hide_input()
# Out:
#         <a id="680735426" href="javascript:toggle_input_680735426()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_680735426;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_680735426 = document.getElementById("680735426");
#                 var cell = link_680735426;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_680735426;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_680735426 = cell.children[i];
#                 }
#                 input_680735426.style.display = "none"; // hide
#
#                 toggle_input_680735426 = function() {
#                     if (input_680735426.style.display == "none") {
#                         input_680735426.style.display = ""; // show
#                         link_680735426.innerHTML = "Hide Input";
#                     } else {
#                         input_680735426.style.display = "none"; // hide
#                         link_680735426.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_680735426 = $("a[id='680735426']");
#                 var cell_680735426 = link_680735426.parents("div.cell:first");
#                 var input_680735426 = cell_680735426.children("div.input");
#                 input_680735426.hide();
#
#                 toggle_input_680735426 = function() {
#                     if (input_680735426.is(':hidden')) {
#                         input_680735426.slideDown();
#                         link_680735426[0].innerHTML = "Hide Input";
#                     } else {
#                         input_680735426.slideUp();
#                         link_680735426[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# # Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time, and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal, not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input,)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[Asquare_probe], label="Decoded esimate")
plt.plot(sim.trange(), np.square(sim.data[input_probe]), label="Input signal squared")
plt.legend(loc="best", fontsize='medium')
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron");
hide_input()
# Out:
#         <a id="803813457" href="javascript:toggle_input_803813457()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_803813457;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_803813457 = document.getElementById("803813457");
#                 var cell = link_803813457;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_803813457;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_803813457 = cell.children[i];
#                 }
#                 input_803813457.style.display = "none"; // hide
#
#                 toggle_input_803813457 = function() {
#                     if (input_803813457.style.display == "none") {
#                         input_803813457.style.display = ""; // show
#                         link_803813457.innerHTML = "Hide Input";
#                     } else {
#                         input_803813457.style.display = "none"; // hide
#                         link_803813457.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_803813457 = $("a[id='803813457']");
#                 var cell_803813457 = link_803813457.parents("div.cell:first");
#                 var input_803813457 = cell_803813457.children("div.input");
#                 input_803813457.hide();
#
#                 toggle_input_803813457 = function() {
#                     if (input_803813457.is(':hidden')) {
#                         input_803813457.slideDown();
#                         link_803813457[0].innerHTML = "Hide Input";
#                     } else {
#                         input_803813457.slideUp();
#                         link_803813457[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same. The only difference is how we're interpreting those spikes. We told Nengo to compute a new set of decoders that estimate the function $x^2$.
#
# In general, the transformation principle determines how we can decode spike trains to compute linear and nonlinear transformations of signals encoded in a population of neurons. We can then project those transformed signals into another population, and repeat the process.  Essentially, this provides a means of computing the neural connection weights to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron");
hide_input()
# Out:
#         <a id="1454484894" href="javascript:toggle_input_1454484894()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1454484894;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1454484894 = document.getElementById("1454484894");
#                 var cell = link_1454484894;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1454484894;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1454484894 = cell.children[i];
#                 }
#                 input_1454484894.style.display = "none"; // hide
#
#                 toggle_input_1454484894 = function() {
#                     if (input_1454484894.style.display == "none") {
#                         input_1454484894.style.display = ""; // show
#                         link_1454484894.innerHTML = "Hide Input";
#                     } else {
#                         input_1454484894.style.display = "none"; // hide
#                         link_1454484894.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1454484894 = $("a[id='1454484894']");
#                 var cell_1454484894 = link_1454484894.parents("div.cell:first");
#                 var input_1454484894 = cell_1454484894.children("div.input");
#                 input_1454484894.hide();
#
#                 toggle_input_1454484894 = function() {
#                     if (input_1454484894.is(':hidden')) {
#                         input_1454484894.slideDown();
#                         link_1454484894[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1454484894.slideUp();
#                         link_1454484894[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal involve solving for the usual decoders, and scaling those decoding weights. Let us flip this sine wave upside down as it is transmitted between two populations (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2,2,3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2,2,2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2,2,4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron");
hide_input()
# Out:
#         <a id="516343759" href="javascript:toggle_input_516343759()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_516343759;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_516343759 = document.getElementById("516343759");
#                 var cell = link_516343759;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_516343759;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_516343759 = cell.children[i];
#                 }
#                 input_516343759.style.display = "none"; // hide
#
#                 toggle_input_516343759 = function() {
#                     if (input_516343759.style.display == "none") {
#                         input_516343759.style.display = ""; // show
#                         link_516343759.innerHTML = "Hide Input";
#                     } else {
#                         input_516343759.style.display = "none"; // hide
#                         link_516343759.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_516343759 = $("a[id='516343759']");
#                 var cell_516343759 = link_516343759.parents("div.cell:first");
#                 var input_516343759 = cell_516343759.children("div.input");
#                 input_516343759.hide();
#
#                 toggle_input_516343759 = function() {
#                     if (input_516343759.is(':hidden')) {
#                         input_516343759.slideDown();
#                         link_516343759[0].innerHTML = "Hide Input";
#                     } else {
#                         input_516343759.slideUp();
#                         link_516343759[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve solving for a new set of decoding weights. Let us add a third population connected to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color='k')
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color='k')
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color='k')
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron");
hide_input()
# Out:
#         <a id="2035657120" href="javascript:toggle_input_2035657120()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2035657120;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2035657120 = document.getElementById("2035657120");
#                 var cell = link_2035657120;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2035657120;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_2035657120 = cell.children[i];
#                 }
#                 input_2035657120.style.display = "none"; // hide
#
#                 toggle_input_2035657120 = function() {
#                     if (input_2035657120.style.display == "none") {
#                         input_2035657120.style.display = ""; // show
#                         link_2035657120.innerHTML = "Hide Input";
#                     } else {
#                         input_2035657120.style.display = "none"; // hide
#                         link_2035657120.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2035657120 = $("a[id='2035657120']");
#                 var cell_2035657120 = link_2035657120.parents("div.cell:first");
#                 var input_2035657120 = cell_2035657120.children("div.input");
#                 input_2035657120.hide();
#
#                 toggle_input_2035657120 = function() {
#                     if (input_2035657120.is(':hidden')) {
#                         input_2035657120.slideDown();
#                         link_2035657120[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2035657120.slideUp();
#                         link_2035657120[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# # Principle 3: Dynamics
#
# So far, we have been considering the values represented by ensembles as generic "signals." However, if we think of them instead as state variables in a dynamical system, then we can apply the methods of control theory or dynamic systems theory to brain models.  Nengo automatically translates from standard dynamical systems descriptions to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics, we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator implemented using this third principle. It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1,0] if t < 0.1 else [0,0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(oscillator, oscillator,
                     transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel('Time (s)')

plt.subplot(1,2,2)
plt.plot(sim.data[oscillator_probe][:,0], sim.data[oscillator_probe][:,1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$');
hide_input()
# Out:
#         <a id="1778247379" href="javascript:toggle_input_1778247379()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1778247379;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1778247379 = document.getElementById("1778247379");
#                 var cell = link_1778247379;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1778247379;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1778247379 = cell.children[i];
#                 }
#                 input_1778247379.style.display = "none"; // hide
#
#                 toggle_input_1778247379 = function() {
#                     if (input_1778247379.style.display == "none") {
#                         input_1778247379.style.display = ""; // show
#                         link_1778247379.innerHTML = "Hide Input";
#                     } else {
#                         input_1778247379.style.display = "none"; // hide
#                         link_1778247379.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1778247379 = $("a[id='1778247379']");
#                 var cell_1778247379 = link_1778247379.parents("div.cell:first");
#                 var input_1778247379 = cell_1778247379.children("div.input");
#                 input_1778247379.hide();
#
#                 toggle_input_1778247379 = function() {
#                     if (input_1778247379.is(':hidden')) {
#                         input_1778247379.slideDown();
#                         link_1778247379[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1778247379.slideUp();
#                         link_1778247379[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
